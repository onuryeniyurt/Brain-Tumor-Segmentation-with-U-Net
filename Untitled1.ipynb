# %%
# !pip install datasets albumentations opencv-python

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt
from datasets import load_dataset
from PIL import Image
import cv2
from sklearn.model_selection import train_test_split

# %%
dataset = load_dataset("dwb2023/brain-tumor-image-dataset-semantic-segmentation")
print(f"Train set: {len(dataset['train'])} sample")
print(f"Validation set: {len(dataset['valid'])} sample")
print(f"Test set: {len(dataset['test'])} sample")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Train set: 1502 sample
# Validation set: 429 sample
# Test set: 215 sample

# %%
train_dataset = dataset['train']

# %%
image = train_dataset[0]["image"]
plt.imshow(image)
plt.axis("off")
plt.show()

# %%
item = train_dataset[0]
image = item["image"]
mask = np.array(item["segmentation"])

plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.title("Image")
plt.imshow(image)
plt.axis("off")

plt.subplot(1,2,2)
plt.title("Mask")
plt.imshow(mask, cmap="gray")
plt.axis("off")

plt.show()

# %%
#train_transform = A.Compose([
#    A.Resize(128,128),
#    A.HorizontalFlip(p=0.5),
#    A.VerticalFlip(p=0.5),
#    A.RandomRotate90(p=0.5),
#    A.RandomBrightnessContrast(p=0.2),
#],is_check_shapes=False)

# %%
def prepare_data(data_split):
    images = []
    masks = []

    for sample in data_split:

        img = sample['image'].resize((128, 128))
        img = np.array(img) / 255.0
        images.append(img)


        mask = np.zeros((128, 128))
        if sample['segmentation']:
            coords = sample['segmentation'][0]

            points = []
            for i in range(0, len(coords), 2):
                x = int(coords[i] * 128 / 640)
                y = int(coords[i+1] * 128 / 640)
                points.append([x, y])

            if len(points) > 2:
                cv2.fillPoly(mask, [np.array(points)], 1)

        masks.append(mask)

    return np.array(images), np.array(masks)[..., np.newaxis]

# %%
X_train, y_train = prepare_data(dataset['train'])
X_val, y_val = prepare_data(dataset['valid'])
X_test, y_test = prepare_data(dataset['test'])

# %%
plt.figure(figsize=(12, 4))
for i in range(3):
    plt.subplot(2, 3, i+1)
    plt.imshow(X_train[i])
    plt.title(f'Image {i+1}')
    plt.axis('off')

    plt.subplot(2, 3, i+4)
    plt.imshow(y_train[i, :, :, 0], cmap='gray')
    plt.title(f'Mask {i+1}')
    plt.axis('off')
plt.tight_layout()
plt.show()

# %%
inputs = layers.Input(shape=(128, 128, 3))

x = layers.Conv2D(32, 3, activation='relu', padding='same')(inputs)
skip1 = x
x = layers.MaxPool2D(2)(x)

x = layers.Conv2D(64, 3, activation='relu', padding='same')(x)
skip2 = x
x = layers.MaxPool2D(2)(x)

x = layers.Conv2D(128, 3, activation='relu', padding='same')(x)

x = layers.UpSampling2D(2)(x)
x = layers.Concatenate()([x, skip2])
x = layers.Conv2D(64, 3, activation='relu', padding='same')(x)

x = layers.UpSampling2D(2)(x)
x = layers.Concatenate()([x, skip1])
x = layers.Conv2D(32, 3, activation='relu', padding='same')(x)

outputs = layers.Conv2D(1, 1, activation='sigmoid', padding='same')(x)

model = keras.Model(inputs, outputs)
model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 128, 128,  │        896 │ input_layer_2[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_6     │ (None, 64, 64,    │          0 │ conv2d_30[0][0]   │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    batch_size=16,
    epochs=20,
    verbose=1
)
# Out:
# Epoch 1/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 327s 3s/step - accuracy: 0.9596 - loss: 0.2562 - val_accuracy: 0.9605 - val_loss: 0.1366
# Epoch 2/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 377s 3s/step - accuracy: 0.9609 - loss: 0.1337 - val_accuracy: 0.9605 - val_loss: 0.1296
# Epoch 3/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 333s 4s/step - accuracy: 0.9602 - loss: 0.1287 - val_accuracy: 0.9605 - val_loss: 0.1215
# Epoch 4/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 378s 4s/step - accuracy: 0.9608 - loss: 0.1193 - val_accuracy: 0.9605 - val_loss: 0.1181
# Epoch 5/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 320s 3s/step - accuracy: 0.9605 - loss: 0.1163 - val_accuracy: 0.9605 - val_loss: 0.1145
# Epoch 6/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 326s 3s/step - accuracy: 0.9608 - loss: 0.1104 - val_accuracy: 0.9608 - val_loss: 0.1103
# Epoch 7/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 380s 3s/step - accuracy: 0.9619 - loss: 0.1087 - val_accuracy: 0.9632 - val_loss: 0.1058
# Epoch 8/20
# ...

# %%
predictions = model.predict(X_test[:6])
predictions
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step
# array([[[[4.02825710e-04],
#          [7.65805999e-06],
#          [1.47165554e-06],
#          ...,
#          [4.79055007e-06],
#          [2.74327140e-05],
#          [1.13290618e-03]],
#
#         [[3.49062293e-06],
#          [7.38424610e-09],
#          [1.23703814e-09],
#          ...,
#          [2.01966550e-08],
#          [2.60721976e-07],
#          [9.26707871e-05]],
#
#         [[5.96809173e-07],
#          [6.43473108e-10],
#          [1.03236836e-10],
#          ...,
#          [3.84572862e-09],
#          [6.91369237e-08],
#          [4.36464070e-05]],
#
#         ...,
#
#         [[1.36589306e-05],
#          [5.20951957e-08],
#          [1.76056929e-08],
#          ...,
#          [1.29493856e-07],
#          [9.92180048e-07],
#          [2.29249737e-04]],
#
#         [[4.57363240e-05],
#          [2.02926756e-07],
#          [6.72915661e-08],
#          ...,
#          [2.88591252e-07],
#          [2.20489869e-06],
# ...

# %%
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
model.save('brain_tumor_unet_fast.keras')

# %%
plt.figure(figsize=(18, 6))
for i in range(6):
    img = X_test[i]
    pred_mask = predictions[i, :, :, 0]

    plt.subplot(2, 6, i+1)
    plt.imshow(img)
    plt.title(f'Image {i+1}')
    plt.axis('off')

    plt.subplot(2, 6, i+7)
    plt.imshow(img)
    plt.imshow(pred_mask, cmap='Reds', alpha=0.5)
    plt.title(f'Prediction {i+1}')
    plt.axis('off')

plt.tight_layout()
plt.show()

# %%
total_params = model.count_params()
total_params
# Out:
# 231617
